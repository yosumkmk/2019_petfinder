# %%
X_train = pd.read_csv('./X_train.csv')

# %%
breed_label = pd.read_csv('../../input/petfinder-adoption-prediction/breed_labels.csv')
state_label = pd.read_csv('../../input/petfinder-adoption-prediction/state_labels.csv')
color_label = pd.read_csv('../../input/petfinder-adoption-prediction/color_labels.csv')

# %%
import pickle
with open('./train_dfs_metadata.pkl', 'rb') as f:
    metadata =  pickle.load(f)

# %%
metadata_desc = metadata.groupby(['PetID'])['metadata_annots_top_desc'].unique()

# %%
metadata=metadata_desc.reset_index()

# %%
color_label
# Out:
#    ColorID ColorName
# 0        1     Black
# 1        2     Brown
# 2        3    Golden
# 3        4    Yellow
# 4        5     Cream
# 5        6      Gray
# 6        7     White

# %%
color_list = ['white', 'black', 'red', 'pink', 'orange', 'blue', 'yellow', 'green', ' purple', 
              ' gray', 'brown', 'gold', 'silver', 'cream', 'beige', 'vermilion']

# %%
len(breed_label)
# Out:
# 307

# %%
breed_label.head()
# Out:
#    BreedID  Type         BreedName
# 0        1     1     Affenpinscher
# 1        2     1      Afghan Hound
# 2        3     1  Airedale Terrier
# 3        4     1            Akbash
# 4        5     1             Akita

# %%
metadata.head()
# Out:
#        PetID                           metadata_annots_top_desc
# 0  0008c5398  [cat small to medium sized cats whiskers cat l...
# 1  000a290e4  [dog dog breed dog like mammal dog breed group...
# 2  000fb9572  [dog dog like mammal mammal vertebrate dog bre...
# 3  0011d7c25  [cat small to medium sized cats cat like mamma...
# 4  00156db4a  [dog dog breed snout street dog dog breed grou...

# %%
int('medium' in ' '.join(metadata.metadata_annots_top_desc[0])
# Out:
# 1

# %%
pet

# %%
metadata_breed = pd.DataFrame(np.zeros((len(metadata), len(breed_label))))

# %%
for i in range(len(metadata)):
    te = ' '.join(metadata.metadata_annots_top_desc[i])
    for c in range(len(breed_label)):
        metadata_breed.iloc[i, c] = int(breed_label.BreedName.iloc[c].lower() in te)

# %%
metadata_color = pd.DataFrame(np.zeros((len(metadata), len(color_list))))

# %%
for i in range(len(metadata)):
    te = ' '.join(metadata.metadata_annots_top_desc[i])
    for c in range(len(color_list)):
        metadata_color.iloc[i, c] = int(color_list[c].lower() in te)

# %%
metadata_color.sum()
# Out:
# 0      269.0
# 1     2339.0
# 2     6233.0
# 3       64.0
# 4        7.0
# 5      219.0
# 6       64.0
# 7       50.0
# 8       35.0
# 9        0.0
# 10      19.0
# 11     440.0
# 12       0.0
# 13       0.0
# 14       0.0
# 15       0.0
# dtype: float64

# %%
color_list = ['white', 'black', 'red', 'pink', 'orange', 'blue', 'yellow', 'green', 'purple',
          'gray', 'brown', 'gold', 'silver', 'cream', 'beige', 'vermilion']

# %%
train
# Out:
#        Type                                 Name  Age  Breed1  Breed2  Gender  \
# 0         2                               Nibble    3     299       0       1
# 1         2                          No Name Yet    1     265       0       1
# 2         1                               Brisco    1     307       0       1
# 3         1                                 Miko    4     307       0       2
# 4         1                               Hunter    1     307       0       1
# 5         2                              No Name    3     266       0       2
# 6         2                                BULAT   12     264     264       1
# 7         1              Siu Pak & Her 6 Puppies    0     307       0       2
# 8         2                              No Name    2     265       0       2
# 9         2                                Kitty   12     265       0       2
# 10        1                                 Bear    2     307       0       1
# ...

# %%
metadata_breed.sum().sum()
# Out:
# 0.0

# %%
train = pd.read_csv('../../input/petfinder-adoption-prediction/train/train.csv')

# %%
train[train.Name == 'No Name']
# Out:
#        Type     Name  Age  Breed1  Breed2  Gender  Color1  Color2  Color3  \
# 26        2  No Name    2     285     265       1       3       0       0
# 27        2  No Name    1     266       0       2       1       0       0
# 156       1  No Name   12     307       0       2       5       7       0
# 160       2  No Name    1     283       0       2       4       7       0
# 323       1  No Name    2     307       0       3       2       6       7
# 432       2  No Name   12     266       0       2       2       0       0
# 501       2  No Name    2     266       0       3       1       4       7
# 1512      1  No Name    2     307       0       1       5       0       0
# 1867      1  No Name  135     195       0       1       6       7       0
# 2506      1  No Name    2     307       0       2       1       2       0
# 2972      2  No Name    1     266       0       1       1       0       0
# 3626      2  No Name    1     265       0       2       6       7       0
# ...

# %%
pd.DataFrame(train.Name.value_counts())
# Out:
#                                        Name
# Baby                                     66
# Lucky                                    64
# No Name                                  54
# Brownie                                  54
# Mimi                                     52
# Blackie                                  49
# Puppy                                    45
# Max                                      39
# Kitty                                    39
# Kittens                                  39
# Oreo                                     36
# Coco                                     35
# Tiger                                    34
# Angel                                    33
# Milo                                     32
# Snowy                                    30
# Bobby                                    30
# Kiki                                     29
# Lucy                                     29
# Lily                                     28
# ...

# %%
import gensim

# %%
name_count.reset_index()
# Out:
#                                       index  Name_count
# 0                                   No Name    8.744081
# 1                                      Baby    0.440205
# 2                                     Lucky    0.426866
# 3                                   Brownie    0.360168
# 4                                      Mimi    0.346829
# 5                                   Blackie    0.326819
# 6                                     Puppy    0.300140
# 7                                       Max    0.260121
# 8                                     Kitty    0.260121
# 9                                   Kittens    0.260121
# 10                                     Oreo    0.240112
# 11                                     Coco    0.233442
# 12                                    Tiger    0.226772
# 13                                    Angel    0.220103
# 14                                     Milo    0.213433
# 15                                    Snowy    0.200093
# ...

# %%
train.Name.fillna('No Name', inplace=True)
name_count = pd.DataFrame(train.Name.value_counts() / len(train) * 100).reset_index()
name_count.columns = ['Name', 'Name_count']
train.merge(name_count, left_on='Name', right_on='Name')
# Out:
#        Type                                 Name  Age  Breed1  Breed2  Gender  \
# 0         2                               Nibble    3     299       0       1
# 1         2                          No Name Yet    1     265       0       1
# 2         2                          No Name Yet    6     266       0       1
# 3         2                          No Name Yet    1     288     266       3
# 4         2                          No Name Yet   60     266       0       2
# 5         1                          No Name Yet    1     307       0       1
# 6         2                          No Name Yet    1     264       0       1
# 7         1                          No Name Yet    1     307       0       3
# 8         1                          No Name Yet    3     307       0       2
# 9         2                          No Name Yet    2     265       0       2
# 10        2                          No Name Yet    1     266       0       3
# ...

# %%
np.isnan(train.Name.values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-e3b4f2411d92> in <module>
# ----> 1 np.isnan(train.Name.values)
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
train[np.isnan(train.Name.values)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-c0b683a52256> in <module>
# ----> 1 train[np.isnan(train.Name.values)]
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
train[train['Name'].apply(lambda x: len(str(x))) < 3]
# Out:
#        Type Name  Age  Breed1  Breed2  Gender  Color1  Color2  Color3  \
# 71        1   H3    1     307     307       2       1       2       0
# 78        1   Z3    2     307     307       1       2       0       0
# 103       1    C    1     307     307       2       1       2       7
# 167       1   BB    2     307       0       2       1       2       0
# 238       1   QQ   22     205       0       2       5       7       0
# 252       1   Y1    2     307     307       2       1       2       0
# 325       1   H1    1     307     307       2       1       2       0
# 366       1   D9    2     307     307       2       2       0       0
# 423       1   Y4    2     307     307       2       1       7       0
# 487       1   Z4    2     307     307       2       2       7       0
# 595       1   BB    6     141     307       2       1       0       0
# 630       2   DD    5     266       0       2       5       0       0
# ...
